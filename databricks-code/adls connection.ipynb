# %%
spark.conf.set(
    "fs.azure.account.key.adlslearningspark.dfs.core.windows.net",
    "ACCESS KEY"
)

# %%
dbutils.fs.ls("abfss://sample-data@adlslearningspark.dfs.core.windows.net/")
# Out:
# [FileInfo(path='abfss://sample-data@adlslearningspark.dfs.core.windows.net/Sales-2017.csv', name='Sales-2017.csv', size=1321941, modificationTime=1752842455000)]

# %%
# File Location 
file_location = "abfss://sample-data@adlslearningspark.dfs.core.windows.net/"

df = spark.read.format("csv").option("inferSchema", "true").option("header", "true").option("delimiter", ",").load(file_location)

# %%
# display(df)
df.printSchema()
# Out:
# root
#  |-- OrderDate: date (nullable = true)
#  |-- StockDate: date (nullable = true)
#  |-- OrderNumber: string (nullable = true)
#  |-- ProductKey: integer (nullable = true)
#  |-- CustomerKey: integer (nullable = true)
#  |-- TerritoryKey: integer (nullable = true)
#  |-- OrderLineItem: integer (nullable = true)
#  |-- OrderQuantity: integer (nullable = true)

# %% [markdown]
# ## Mehod 2: Creating Mount Point

# %%
dbutils.fs.mount(
    source = "wasbs://sample-data@adlslearningspark.blob.core.windows.net",
    mount_point='/mnt/adls_test',
    extra_configs={"fs.azure.account.key.adlslearningspark.blob.core.windows.net":"ACCESS KEY"}
)
# Out:
# True

# %%
dbutils.fs.ls('/mnt/adls_test')
# Out:
# [FileInfo(path='dbfs:/mnt/adls_test/Sales-2017.csv', name='Sales-2017.csv', size=1321941, modificationTime=1752842455000)]

# %%
dbutils.fs.mounts()
# Out:
# [MountInfo(mountPoint='/databricks-datasets', source='databricks-datasets', encryptionType=''),
#  MountInfo(mountPoint='/Volumes', source='UnityCatalogVolumes', encryptionType=''),
#  MountInfo(mountPoint='/databricks/mlflow-tracking', source='databricks/mlflow-tracking', encryptionType=''),
#  MountInfo(mountPoint='/databricks-results', source='databricks-results', encryptionType=''),
#  MountInfo(mountPoint='/mnt/adls_test', source='wasbs://sample-data@adlslearningspark.blob.core.windows.net', encryptionType=''),
#  MountInfo(mountPoint='/databricks/mlflow-registry', source='databricks/mlflow-registry', encryptionType=''),
#  MountInfo(mountPoint='/Volume', source='DbfsReserved', encryptionType=''),
#  MountInfo(mountPoint='/volumes', source='DbfsReserved', encryptionType=''),
#  MountInfo(mountPoint='/', source='DatabricksRoot', encryptionType=''),
#  MountInfo(mountPoint='/volume', source='DbfsReserved', encryptionType='')]
